# %% [markdown]
# Note that this Notebook isn't quite done yet... I had to fix something in the prices package that isn't quite ready!

# %%
import prices
import fitmodels

# %%
help(fitmodels)
# Out:
# Help on module fitmodels:
#
# NAME
#     fitmodels
#
# FUNCTIONS
#     area(*args)
#
#     areaFront(*args)
#
#     areaFront_nesterov(*args)
#
#     area_nesterov(*args)
#
# FILE
#     c:\users\twwilko\documents\python scripts\acm 612\git repo\intro2dsa\project 1\fitmodels.py

# %%
dataTestFeatures=prices.pd.read_csv("DATA/test.csv")

# Replace NaN values with the mean of not-NaN values
indexNaN=prices.np.isnan(dataTest['LotFrontage'])
replaceNaN=prices.np.array(dataTest['LotFrontage'][-indexNaN].mean()).round()
columnNaN=dataTest['LotFrontage'].values

columnNaN[indexNaN] = replaceNaN
dataTestFeatures['LotFrontage']=columnNaN

del(indexNaN,replaceNaN,columnNaN)
dataTestFeatures[:10]
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
# 5  1466          60       RL         75.0    10000   Pave   NaN      IR1
# 6  1467          20       RL         69.0     7980   Pave   NaN      IR1
# 7  1468          60       RL         63.0     8402   Pave   NaN      IR1
# 8  1469          20       RL         85.0    10176   Pave   NaN      Reg
# 9  1470          20       RL         70.0     8400   Pave   NaN      Reg
#
#   LandContour Utilities      ...       ScreenPorch PoolArea PoolQC  Fence  \
# 0         Lvl    AllPub      ...               120        0    NaN  MnPrv
# 1         Lvl    AllPub      ...                 0        0    NaN    NaN
# 2         Lvl    AllPub      ...                 0        0    NaN  MnPrv
# 3         Lvl    AllPub      ...                 0        0    NaN    NaN
# 4         HLS    AllPub      ...               144        0    NaN    NaN
# 5         Lvl    AllPub      ...                 0        0    NaN    NaN
# 6         Lvl    AllPub      ...                 0        0    NaN  GdPrv
# 7         Lvl    AllPub      ...                 0        0    NaN    NaN
# 8         Lvl    AllPub      ...                 0        0    NaN    NaN
# 9         Lvl    AllPub      ...                 0        0    NaN  MnPrv
#
#   MiscFeature MiscVal MoSold  YrSold  SaleType  SaleCondition
# 0         NaN       0      6    2010        WD         Normal
# 1        Gar2   12500      6    2010        WD         Normal
# 2         NaN       0      3    2010        WD         Normal
# 3         NaN       0      6    2010        WD         Normal
# 4         NaN       0      1    2010        WD         Normal
# 5         NaN       0      4    2010        WD         Normal
# 6        Shed     500      3    2010        WD         Normal
# 7         NaN       0      5    2010        WD         Normal
# 8         NaN       0      2    2010        WD         Normal
# 9         NaN       0      4    2010        WD         Normal
#
# [10 rows x 80 columns]

# %%
dataTestLabels=prices.pd.read_csv("DATA/sample_submission.csv")
dataTestLabels[:10]
# Out:
#      Id      SalePrice
# 0  1461  169277.052498
# 1  1462  187758.393989
# 2  1463  183583.683570
# 3  1464  179317.477511
# 4  1465  150730.079977
# 5  1466  177150.989247
# 6  1467  172070.659229
# 7  1468  175110.956520
# 8  1469  162011.698832
# 9  1470  160726.247831

# %%
dataTest=dataTestLabels.set_index('Id').join(dataTestFeatures.set_index('Id'))[['LotArea','LotFrontage','SalePrice']]
dataTest[:10]
# Out:
#       LotArea  LotFrontage      SalePrice
# Id
# 1461    11622         80.0  169277.052498
# 1462    14267         81.0  187758.393989
# 1463    13830         74.0  183583.683570
# 1464     9978         78.0  179317.477511
# 1465     5005         43.0  150730.079977
# 1466    10000         75.0  177150.989247
# 1467     7980         69.0  172070.659229
# 1468     8402         63.0  175110.956520
# 1469    10176         85.0  162011.698832
# 1470     8400         70.0  160726.247831

# %%
predArea=fitmodels.area(dataTest['LotArea'].values)
predArea
# Out:
# array([20615.86879849, 20615.86879849, 20615.86879849, ...,
#        20615.86879849, 20615.86879849, 20615.86879849])

# %%
dataTest['LotArea'].values
# Out:
# array([11622, 14267, 13830, ..., 20000, 10441,  9627], dtype=int64)

# %%
args=[dataTest['LotArea'].values]
res=prices.np.zeros(len(args[0]))
print(res)
weights=[20000,6]
if len(weights)==len(args)+1:
    for x in range(1,len(args)):
        print(x)
        res+=weights[x]*args[x-1]
        print(res)
    res+=weights[0]
    print(res)
res
# Out:
# [0. 0. 0. ... 0. 0. 0.]
# [20000. 20000. 20000. ... 20000. 20000. 20000.]
# array([20000., 20000., 20000., ..., 20000., 20000., 20000.])

# %%
weights[1]
# Out:
# 6

# %%
args[0]
# Out:
# array([11622, 14267, 13830, ..., 20000, 10441,  9627], dtype=int64)

# %%
list(range(1,len(args)+1))
# Out:
# [1]
