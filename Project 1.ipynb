# %%
import pandas  #bringing in panda module
hdf = pandas.read_csv('train.csv') #read in the csv file

# %%
import numpy as np

# %%
m=len(hdf)                      # will be important for amount of ones to include in array
a = hdf['LotArea'].values       #lot area array
a0 = np.ones(m,dtype=int)       # array of ones to combine and make into vector
Y= hdf['SalePrice'].values          # sale price array

# %%
X=np.array([a,a0]).T   
X
# Out:
# array([[ 8450,     1],
#        [ 9600,     1],
#        [11250,     1],
#        ...,
#        [ 9042,     1],
#        [ 9717,     1],
#        [ 9937,     1]], dtype=int64)

# %%
def loss(X,w,Y):
    n=len(y)
    return np.sum(((np.dot(X,w)-Y)**2)/n) #add everything up loss function tells us how bad line/model is

# %%
def lw(X,w,Y):
    n = len(Y)
    lw1 = np.dot(X,w)-Y
    return np.sum((np.dot(lw1, X)*2)/n)

# %%
def lb(X,w,Y):
    n = len(Y)
    return np.sum(((np.dot(X,w)-Y)*2)/n)

# %%
stepsize = 0.00000005
w=np.array([100000,0])
for i in range(3):
    w = w - np.array([lw(X,w,Y), lb(X,w,Y)])*stepsize
    plt.scatter(X.T[0], Y)
    plt.plot(x, 'r')
    plt.show()
    print(loss(X,w,Y))
print(w)
# Out:
# 8.419183038267932e+20
# 3.373454729705729e+23
# 1.3516984673451911e+26
# [-8.01980396e+08 -4.01354741e+04]

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
x = np.linspace(100000, 500000, 50000)
plt.scatter(X.T[0], Y)
plt.plot(x, 'r')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.9977690675827">
